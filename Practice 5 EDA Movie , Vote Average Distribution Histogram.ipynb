# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import warnings

warnings.filterwarnings('ignore')

# %%
movie = pd.read_csv('movies.csv')
credit = pd.read_csv('credits.csv')

# %%
movie_credit = pd.merge(movie , credit , left_on = 'id' , right_on = 'movie_id')
movie_credit
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
Vote_average = movie_credit['vote_average'].values
Vote_average
# Out:
# array([7.2, 6.9, 6.3, ..., 7. , 5.7, 6.3])

# %%
vote_average = movie_credit['vote_average'].values

# Create Histogram

plt.figure(figsize = (10,6))

plt.hist(vote_average , bins =10 , color = 'skyblue' , edgecolor = 'black'  , alpha = 0.7)

plt.xlabel('Vote_Average' , fontsize = 14)
plt.ylabel('Frequency' , fontsize = 14)
plt.title('Vote Average Distribution' , fontsize = 16)


plt.show()

# %%
vote_average = movie_credit['vote_average'].values

# Create Histogram

plt.figure(figsize = (10,6))

plt.hist(vote_average , bins =10 , color = 'skyblue' , edgecolor = 'black'  , alpha = 0.7)

plt.xlabel('Vote_Average' , fontsize = 14)
plt.ylabel('Frequency' , fontsize = 14)
plt.title('Vote Average Distribution' , fontsize = 16)

# Customize Appearance

plt.grid(True , linestyle = '--' , alpha = 0.8)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)


plt.show()

# %%
vote_average = movie_credit['vote_average'].values

# Create Histogram

plt.figure(figsize = (10,6))

plt.hist(vote_average , bins =10 , color = 'skyblue' , edgecolor = 'black'  , alpha = 0.7)

plt.xlabel('Vote_Average' , fontsize = 14)
plt.ylabel('Frequency' , fontsize = 14)
plt.title('Vote Average Distribution' , fontsize = 16)

# Customize Appearance

plt.grid(True , linestyle = '--' , alpha = 0.8)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)

#gca

plt.gca().spines['top'].set_visible(0.5)
plt.gca().spines['right'].set_visible(0.5)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)

#add background color

plt.gca().set_facecolor('#f7f7f7')
plt.tight_layout()



plt.show()
